# %%
import sys
sys.path.append("./demo")
from train_mask_rcnn_demo import *
# Out:
# /home/aman17/Mask_RCNN/rcnn/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/aman17/Mask_RCNN/rcnn/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/aman17/Mask_RCNN/rcnn/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
annotations_path = "annotations_train.json"

# %%
dataset_train = load_image_dataset(os.path.join("./", annotations_path), "./trainingDataset_mrcnn", "train")
dataset_val = load_image_dataset(os.path.join("./", annotations_path), "./trainingDataset_mrcnn", "val")
class_number = dataset_train.count_classes()
print('Train: %d' % len(dataset_train.image_ids))
print('Validation: %d' % len(dataset_val.image_ids))
print("Classes: {}".format(class_number))
# Out:
# Annotation json path:  ./annotations_train.json
# Annotation json path:  ./annotations_train.json
# Train: 976
# Validation: 122
# Classes: 1

# %%
display_image_samples(dataset_train)

# %%
test_model, inference_config = load_test_model(class_number)
# Out:
# Loading weights from  /home/aman17/Downloads/r-cnn-instance-segmentation-master/logs/object20220106T2012/mask_rcnn_object_0001.h5
# Re-starting from epoch 1

# %%
test_random_image(test_model, dataset_val, inference_config)
# Out:
# original_image           shape: (256, 256, 3)         min:    0.00000  max:  255.00000  uint8
# Trained model result
# Processing 1 images
# image                    shape: (256, 256, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 256, 256, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  256.00000  int64
# anchors                  shape: (1, 16368, 4)         min:   -1.41976  max:    2.16878  float32
# Annotation
